# %% [markdown]
# <a href="https://colab.research.google.com/github/AnanyaCSE-039/BIS-Lab/blob/main/BIS_Lab_4_Cuckoo_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Objective function: Rastrigin Function
def rastrigin(x):
    A = 10
    return A * len(x) + sum(xi**2 - A * np.cos(2 * np.pi * xi) for xi in x)

# Lévy flight function for generating random steps
def levy_flight(beta=1.5, dim=2):
    sigma_u = np.power(np.math.gamma(1 + beta) * np.sin(np.pi * beta / 2) / np.math.gamma((1 + beta) / 2) / np.power(2, (beta - 1) / 2), 1 / beta)
    sigma_v = 1
    u = np.random.normal(0, sigma_u, dim)
    v = np.random.normal(0, sigma_v, dim)
    return u / np.power(np.abs(v), 1 / beta)

# Cuckoo Search Algorithm
class CuckooSearch:
    def __init__(self, func, dim, population_size, max_generations, pa=0.25, beta=1.5, lower_bound=-5, upper_bound=5):
        self.func = func                # Objective function
        self.dim = dim                  # Dimension of the problem
        self.population_size = population_size  # Number of nests (solutions)
        self.max_generations = max_generations  # Maximum number of generations
        self.pa = pa                    # Probability of alien eggs (nest replacement)
        self.beta = beta                # Lévy flight exponent
        self.lower_bound = lower_bound  # Lower bound of the search space
        self.upper_bound = upper_bound  # Upper bound of the search space

        # Initialize population (nests)
        self.nests = np.random.uniform(self.lower_bound, self.upper_bound, (self.population_size, self.dim))
        self.fitness = np.array([self.func(nest) for nest in self.nests])  # Fitness of each nest
        self.best_nest = self.nests[np.argmin(self.fitness)]  # Best solution found
        self.best_fitness = np.min(self.fitness)  # Best fitness value

    # Update nests using Lévy flights and objective function evaluations
    def generate_new_nests(self):
        new_nests = []
        for i in range(self.population_size):
            step = levy_flight(self.beta, self.dim)
            new_nest = self.nests[i] + step
            # Apply boundary check
            new_nest = np.clip(new_nest, self.lower_bound, self.upper_bound)
            new_nests.append(new_nest)
        return np.array(new_nests)

    # Main cuckoo search algorithm
    def search(self):
        history = []  # To record the best fitness values over generations

        for generation in range(self.max_generations):
            # Generate new nests based on Lévy flight
            new_nests = self.generate_new_nests()
            new_fitness = np.array([self.func(nest) for nest in new_nests])

            # Replace nests with new ones if they are better
            for i in range(self.population_size):
                if new_fitness[i] < self.fitness[i] or np.random.rand() < self.pa:
                    self.nests[i] = new_nests[i]
                    self.fitness[i] = new_fitness[i]

            # Find the best nest in the current population
            current_best_fitness = np.min(self.fitness)
            current_best_nest = self.nests[np.argmin(self.fitness)]

            # Update the global best solution
            if current_best_fitness < self.best_fitness:
                self.best_fitness = current_best_fitness
                self.best_nest = current_best_nest

            # Record the best fitness for the current generation
            history.append(self.best_fitness)
            print(f"Generation {generation+1}: Best fitness = {self.best_fitness}")

        return self.best_nest, self.best_fitness, history

# Analyze the Cuckoo Search Algorithm
def analyze_cuckoo_search():
    # Set up parameters for Cuckoo Search
    dim = 2
    population_size = 50
    max_generations = 100
    cuckoo_search = CuckooSearch(func=rastrigin, dim=dim, population_size=population_size, max_generations=max_generations)

    # Run the Cuckoo Search algorithm
    best_nest, best_fitness, history = cuckoo_search.search()

    # Plot the convergence curve
    plt.plot(history)
    plt.title("Convergence Curve of Cuckoo Search Algorithm")
    plt.xlabel("Generation")
    plt.ylabel("Best Fitness")
    plt.show()

    print(f"Best solution found: {best_nest}")
    print(f"Best fitness: {best_fitness}")

# Run the analysis
analyze_cuckoo_search()
# Out:
# <ipython-input-5-771e81aa8b60>:11: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   sigma_u = np.power(np.math.gamma(1 + beta) * np.sin(np.pi * beta / 2) / np.math.gamma((1 + beta) / 2) / np.power(2, (beta - 1) / 2), 1 / beta)
# Generation 1: Best fitness = 2.6834179370017637
# Generation 2: Best fitness = 2.6834179370017637
# Generation 3: Best fitness = 2.6834179370017637
# Generation 4: Best fitness = 2.6834179370017637
# Generation 5: Best fitness = 2.6834179370017637
# Generation 6: Best fitness = 2.6834179370017637
# Generation 7: Best fitness = 2.226449279276842
# Generation 8: Best fitness = 2.226449279276842
# Generation 9: Best fitness = 2.226449279276842
# Generation 10: Best fitness = 2.226449279276842
# Generation 11: Best fitness = 2.226449279276842
# Generation 12: Best fitness = 1.5305664271612685
# Generation 13: Best fitness = 1.5305664271612685
# Generation 14: Best fitness = 1.5305664271612685
# Generation 15: Best fitness = 1.5305664271612685
# Generation 16: Best fitness = 1.5305664271612685
# Generation 17: Best fitness = 1.5305664271612685
# Generation 18: Best fitness = 1.5305664271612685
# Generation 19: Best fitness = 1.5305664271612685
# Generation 20: Best fitness = 1.5305664271612685
# Generation 21: Best fitness = 1.5305664271612685
# Generation 22: Best fitness = 1.5305664271612685
# Generation 23: Best fitness = 1.5305664271612685
# Generation 24: Best fitness = 1.4338954218445537
# Generation 25: Best fitness = 1.4338954218445537
# Generation 26: Best fitness = 1.4338954218445537
# Generation 27: Best fitness = 1.4338954218445537
# Generation 28: Best fitness = 1.4338954218445537
# Generation 29: Best fitness = 1.4338954218445537
# Generation 30: Best fitness = 1.4338954218445537
# Generation 31: Best fitness = 1.4338954218445537
# Generation 32: Best fitness = 1.4338954218445537
# Generation 33: Best fitness = 1.4338954218445537
# Generation 34: Best fitness = 1.4338954218445537
# Generation 35: Best fitness = 1.4338954218445537
# Generation 36: Best fitness = 1.4338954218445537
# Generation 37: Best fitness = 1.4338954218445537
# Generation 38: Best fitness = 1.4338954218445537
# Generation 39: Best fitness = 1.4338954218445537
# Generation 40: Best fitness = 1.4338954218445537
# Generation 41: Best fitness = 1.4338954218445537
# Generation 42: Best fitness = 1.4338954218445537
# Generation 43: Best fitness = 1.4338954218445537
# Generation 44: Best fitness = 1.4338954218445537
# Generation 45: Best fitness = 1.4338954218445537
# Generation 46: Best fitness = 1.4338954218445537
# Generation 47: Best fitness = 1.4338954218445537
# Generation 48: Best fitness = 1.4338954218445537
# Generation 49: Best fitness = 1.4338954218445537
# Generation 50: Best fitness = 1.4338954218445537
# Generation 51: Best fitness = 1.4338954218445537
# Generation 52: Best fitness = 1.4338954218445537
# Generation 53: Best fitness = 1.4338954218445537
# Generation 54: Best fitness = 1.4338954218445537
# Generation 55: Best fitness = 1.4338954218445537
# Generation 56: Best fitness = 1.4338954218445537
# Generation 57: Best fitness = 1.4338954218445537
# Generation 58: Best fitness = 1.4338954218445537
# Generation 59: Best fitness = 1.4338954218445537
# Generation 60: Best fitness = 1.4338954218445537
# Generation 61: Best fitness = 1.4338954218445537
# Generation 62: Best fitness = 1.4338954218445537
# Generation 63: Best fitness = 1.4338954218445537
# Generation 64: Best fitness = 1.4338954218445537
# Generation 65: Best fitness = 1.4338954218445537
# Generation 66: Best fitness = 1.4338954218445537
# Generation 67: Best fitness = 1.4338954218445537
# Generation 68: Best fitness = 1.4338954218445537
# Generation 69: Best fitness = 1.4338954218445537
# Generation 70: Best fitness = 1.4338954218445537
# Generation 71: Best fitness = 1.4338954218445537
# Generation 72: Best fitness = 1.4338954218445537
# Generation 73: Best fitness = 1.4338954218445537
# Generation 74: Best fitness = 1.4338954218445537
# Generation 75: Best fitness = 1.4338954218445537
# Generation 76: Best fitness = 1.4338954218445537
# Generation 77: Best fitness = 1.4338954218445537
# Generation 78: Best fitness = 1.4338954218445537
# Generation 79: Best fitness = 1.4338954218445537
# Generation 80: Best fitness = 1.4338954218445537
# Generation 81: Best fitness = 1.4338954218445537
# Generation 82: Best fitness = 1.4338954218445537
# Generation 83: Best fitness = 1.4338954218445537
# Generation 84: Best fitness = 1.4338954218445537
# Generation 85: Best fitness = 1.4338954218445537
# Generation 86: Best fitness = 1.4338954218445537
# Generation 87: Best fitness = 1.4338954218445537
# Generation 88: Best fitness = 1.0909991548821907
# Generation 89: Best fitness = 1.0909991548821907
# Generation 90: Best fitness = 1.0909991548821907
# Generation 91: Best fitness = 0.7797772941681842
# Generation 92: Best fitness = 0.7797772941681842
# Generation 93: Best fitness = 0.7797772941681842
# Generation 94: Best fitness = 0.7797772941681842
# Generation 95: Best fitness = 0.7797772941681842
# Generation 96: Best fitness = 0.7797772941681842
# Generation 97: Best fitness = 0.7797772941681842
# Generation 98: Best fitness = 0.7797772941681842
# Generation 99: Best fitness = 0.7797772941681842
# Generation 100: Best fitness = 0.7797772941681842
# Best solution found: [0.20554604 2.10218634]
# Best fitness: 0.7797772941681842
